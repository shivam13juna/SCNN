# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from PIL import Image, ImageFilter
from matplotlib import cm
import seaborn as sns
import math


# %matplotlib inline

# %%
# im1 = cv2.imread('4_1_avg.png')
im2 = cv2.imread('5_2_avg.png')
im3 = cv2.imread('5_3_avg.png')
# im4 = cv2.imread('4_4_avg.png')

# %%
# im = im1+im2+im3+im4
im = im2+im3

# %%
gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)

# %%
plt.figure(figsize = (100, 10))
plt.imshow(gray, cmap='gray')

# %%
the = 0
mid = 0
for i in range(288):
    if np.max(gray[i]) > 0:
        the = i
        print(i)
        break
mid = math.floor((gray.shape[0] - the)/2) + the
# Out:
# 143

# %%
np.max(gray[215])
# Out:
# 194

# %%
mid
# Out:
# 215

# %%
plt.plot(gray[mid])

# %%
stind = 0
midd = 0
phase = 0
end = 0

for i in range(800):
    if gray[mid][i]>50 and midd ==0 and stind ==0:
        print("Assigning stind: ", i)
        stind = i
        midd = 1
    if midd==1 and stind!= 0 and gray[mid][i]<10:
        phase = 1
    if phase==1 and gray[mid][i] > 50:
        end = i
        break
# Out:
# Assigning stind:  158

# %%
print(stind)
print(end)
# Out:
# 158
# 415

# %%
themid = math.floor((stind + end)/2)

# %%
themid
# Out:
# 286

# %%
gray[mid][themid-5:themid+5] = 255

# %%
plt.plot(gray[mid])

# %%
gray[215 - 5: 220][:, themid].shape
# Out:
# (10,)

# %%
gray[mid-1:mid+1] = 255
gray[mid-5:mid+5][:, themid] = 255

# %%
plt.figure(figsize = (100, 10))
plt.imshow(gray, cmap='gray')

# %%
def FrameCapture(path): 
    array = []
      
    # Path to video file 
    vidObj = cv2.VideoCapture(path) 
  
    # Used as counter variable 
    count = 0
  
    # checks whether frames were extracted 
    success = 1
  
    while success: 
  
        # vidObj object calls read 
        # function extract frames 
        success, image = vidObj.read() 
  
        # Saves the frames with frame-count 
        try:
            im = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            array.append(im)
#             plt.imshow(gray, cmap='gray')
#             cv2.imwrite("frame%d.jpg" % count, image) 
        except:
            return array
  
        count += 1

# %%
into = FrameCapture('data/sample.mp4')
